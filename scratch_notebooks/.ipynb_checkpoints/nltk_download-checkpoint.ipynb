# %%
import nltk

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
# ...
#        |
#        | Downloading package abc to /home/vishal/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /home/vishal/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to
#        |     /home/vishal/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /home/vishal/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /home/vishal/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /home/vishal/nltk_data...
# ...
