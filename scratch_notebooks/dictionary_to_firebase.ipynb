# %%
import os, subprocess, json, re

# %%
from nltk.corpus import wordnet as wn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ce72280a8844> in <module>()
# ----> 1 from nltk.corpus import wordnet as wn
#
# ModuleNotFoundError: No module named 'nltk'

# %%
from nltk.corpus import brown
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-bf7ffca5355a> in <module>()
# ----> 1 from nltk.corpus import brown
#
# ModuleNotFoundError: No module named 'nltk'

# %%
from nltk.tokenize import RegexpTokenizer

# %%
news_text = brown.words(categories='news')
news_text = " ".join(news_text)
tokenizer = RegexpTokenizer(r'\w+')
news_text = list(set(tokenizer.tokenize(news_text)))
print(news_text)
# Out:
# ['march', 'spotlight', 'symphony', 'Commies', 'inning', 'distressing', 'favorite', 'belatedly', 'G', 'past', 'frankness', 'compacts', 'remove', 'Hoffa', 'Ludlow', 'lies', 'whom', 'thunderous', 'Ben', 'fallout', 'Stranahan', 'extent', 'Gin', 'niece', 'blast', 'stuck', 'Has', 'stations', 'Congress', 'detriment', 'Rimini', 'jotted', 'allegations', 'mending', 'cities', 'Glen', 'inlaid', 'enforcers', 'either', 'Co', 'bright', 'Investment', 'stoppages', 'miracle', 'Accounting', 'Frank', 'Governments', 'boasting', 'concerned', 'Saul', 'Though', 'television', 'campaigning', 'definite', 'conservative', 'through', 'Delaware', 'shrimp', 'liens', 'Eight', 'Confusion', 'strayed', 'same', 'initial', 'Beesemyers', 'revenues', 'telephone', 'Coral', 'performing', 'Lenygon', 'being', 'translated', 'unemployment', 'venture', 'meddle', 'sharply', 'Md', 'Jr', 'discussion', 'realty', 'occupying', 'size', 'thirty', 'daughter', 'Hail', 'collaborators', 'P', 'necessitate', 'warehouseman', 'Lives', 'accomplishment', 'U', '229', 'possible', 'crucified', 'halfbacks', 'Beardens', 'Pate', 'purse', 'chests', 'Newark', 'between', 'fiercest', 'truths', 'Hector', 'Patrolman', 'analysis', 'Mohammedanism', 'accomodations', 'Reconstruction', 'appearances', 'papers', 'rapped', 'Socialist', 'whirling', 'Crosby', 'emasculated', 'lengthy', 'closed', 'All', '149', 'While', 'onslaught', 'Charley', '169', 'musicians', 'Houston', 'know', 'case', 'signatures', 'Macwhyte', 'diamond', 'decided', 'denied', 'sat', 'Communisn', 'briefs', 'expensive', 'ugly', 'dominate', 'Uncas', 'turbines', 'last', 'trick', 'orderly', 'invites', 'oft', 'enabled', 'Gauer', 'Raymond', 'Its', 'may', 'offs', '206', 'conventional', 'council', 'D', 'adjoining', 'federal', 'filial', 'experience', 'ICC', 'providing', 'affixed', 'pour', 'Vern', 'bundles', 'Almost', 'Mining', 'teardrop', 'acquaintance', 'memory', 'bedtime', 'suffragettes', 'base', 'Debate', 'alter', 'smashed', 'confided', '182', 'Llewellyn', 'spurt', 'mighty', 'further', 'Pratt', 'vast', 'nightclubs', 'spring', 'retiring', 'deeply', 'paganism', 'techniques', 'Starting', 'collision', 'jail', 'shoe', 'stomachs', 'drafts', 'height', 'uncertain', 'denote', 'handle', 'pink', 'postgraduate', 'Burgher', 'opinion', 'before', 'Chronicle', 'inside', 'south', 'entirety', 'lady', 'Benington', 'Associated', 'contracts', 'Kika', 'pedestal', 'forswears', '58', 'outlets', 'hostages', '555', 'juniors', 'thigh', 'ease', 'professors', 'missiles', 'Missionary', 'rentals', 'Lawn', 'flour', 'Conrad', 'Adamson', 'railing', 'Walbridge', 'baton', 'my', 'managed', 'Arden', 'N', 'wellknown', 'fearing', 'Religious', 'revamped', 'crippled', 'readiness', 'DiSimone', 'position', 'Pearson', 'share', 'Sabbath', 'Calling', 'sit', 'statewide', 'McDaniel', 'Salter', 'Hays', 'organize', 'scientist', 'Without', 'Anna', 'flat', 'warbling', 'Twelve', 'steam', 'Dewey', 'some', 'protect', 'promotional', 'Jorda', '617', 'Reputedly', 'pattern', 'divorce', 'Symonds', 'Grover', '260', 'clashes', 'slender', 'Jane', 'losing', 'buying', 'Christianity', 'abortive', 'promising', 'Admitting', 'win', 'overhauling', 'ebony', 'slowed', 'aftermath', 'Campagnoli', 'outfield', 'Other', 'Arkansas', 'top', 'ballet', 'upped', 'duffers', 'her', 'Alpha', 'logistical', 'trusting', 'except', 'fires', 'testing', 'reduction', 'wherever', 'appraisers', 'picketed', 'separators', 'shortage', 'Trade', 'hardly', 'titular', 'Seats', 'worth', 'violation', 'Blvd', '25', 'Bet', 'massive', 'shift', 'Wolcott', 'lost', 'grooming', 'Burbank', 'Local', 'radioed', 'borrower', 'circulation', 'thought', 'Swelling', 'page', 'honest', 'culmination', 'Broncos', 'Clara', 'unite', 'Pittsburgh', 'Myron', 'complexity', 'Owens', 'summit', 'speakers', 'evaluate', 'Which', 'Cerv', 'widespread', 'haute', 'American', '1970s', 'fulfill', 'winning', 'intangible', 'consistently', 'boss', 'Marie', 'transports', 'needed', 'la', 'Jude', 'denunciation', 'battalions', 'Gevurtz', 'means', 'Queen', 'Wrigley', 'gauntlet', 'Malmud', 'Adcock', ...

# %%
list_of_synsets = []
for word in news_text:
    list_of_synsets.extend(wn.synsets(word))
print(list_of_synsets)
# Out:
# [Synset('march.n.01'), Synset('march.n.02'), Synset('march.n.03'), Synset('march.n.04'), Synset('borderland.n.01'), Synset('marching_music.n.01'), Synset('master_of_architecture.n.01'), Synset('march.v.01'), Synset('march.v.02'), Synset('march.v.03'), Synset('demonstrate.v.04'), Synset('parade.v.01'), Synset('march.v.06'), Synset('border.v.05'), Synset('limelight.n.01'), Synset('spotlight.n.02'), Synset('foreground.v.01'), Synset('spotlight.v.02'), Synset('symphony.n.01'), Synset('symphony_orchestra.n.01'), Synset('communist.n.02'), Synset('inning.n.01'), Synset('straiten.v.01'), Synset('distress.v.02'), Synset('distressing.s.01'), Synset('deplorable.s.01'), Synset('favorite.n.01'), Synset('darling.n.01'), Synset('front-runner.n.01'), Synset('favorite.s.01'), Synset('favored.s.01'), Synset('late.r.01'), Synset('gram.n.01'), Synset('guanine.n.01'), Synset('deoxyguanosine_monophosphate.n.01'), Synset('thousand.n.01'), Synset('g.n.05'), Synset('gigabyte.n.01'), Synset('gigabyte.n.02'), Synset('gravitational_constant.n.01'), Synset('g.n.09'), Synset('past.n.01'), Synset('past.n.02'), Synset('past.n.03'), Synset('past.a.01'), Synset('past.s.02'), Synset('by.r.01'), Synset('candor.n.02'), Synset('frankness.n.02'), Synset('compact.n.01'), Synset('covenant.n.01'), Synset('compact.n.03'), Synset('compact.v.01'), Synset('pack.v.03'), Synset('compress.v.01'), Synset('compress.v.02'), Synset('remove.n.01'), Synset('remove.v.01'), Synset('remove.v.02'), Synset('get_rid_of.v.01'), Synset('take_out.v.01'), Synset('remove.v.05'), Synset('absent.v.01'), Synset('murder.v.01'), Synset('remove.v.08'), Synset('hoffa.n.01'), Synset('lie.n.01'), Synset('lie.n.02'), Synset('lie.n.03'), Synset('lie.v.01'), Synset('lie.v.02'), Synset('dwell.v.02'), Synset('lie.v.04'), Synset('lie.v.05'), Synset('lie.v.06'), Synset('lie_down.v.01'), Synset('deafening.s.01'), Synset('thunderous.s.02'), Synset('ben.n.01'), Synset('fallout.n.01'), Synset('side_effect.n.02'), Synset('extent.n.01'), Synset('extent.n.02'), Synset('gin.n.01'), Synset('snare.n.05'), Synset('cotton_gin.n.01'), Synset('gin.n.04'), Synset('gin.v.01'), Synset('gin.v.02'), Synset('niece.n.01'), Synset('blast.n.01'), Synset('bang.n.02'), Synset('gust.n.01'), Synset('blast.n.04'), Synset('good_time.n.01'), Synset('fire.n.09'), Synset('blast.v.01'), Synset('smash.v.01'), Synset('blast.v.03'), Synset('blast.v.04'), Synset('blast.v.05'), Synset('blast.v.06'), Synset('blast.v.07'), Synset('savage.v.02'), Synset('blast.v.09'), Synset('blast.v.10'), Synset('lodge.v.02'), Synset('stay.v.02'), Synset('adhere.v.06'), Synset('stick.v.04'), Synset('stick.v.05'), Synset('adhere.v.04'), Synset('stand_by.v.03'), Synset('stick.v.08'), Synset('stick.v.09'), Synset('stick.v.10'), Synset('stick.v.11'), Synset('stick.v.12'), Synset('stick.v.13'), Synset('cling.v.01'), Synset('stick.v.15'), Synset('perplex.v.01'), Synset('stuck.a.01'), Synset('stuck.s.02'), Synset('hour_angle.n.02'), Synset('have.v.01'), Synset('have.v.02'), Synset('experience.v.03'), Synset('own.v.01'), Synset('get.v.03'), Synset('consume.v.02'), Synset('have.v.07'), Synset('hold.v.03'), Synset('have.v.09'), Synset('have.v.10'), Synset('have.v.11'), Synset('have.v.12'), Synset('induce.v.02'), Synset('accept.v.02'), Synset('receive.v.01'), Synset('suffer.v.02'), Synset('have.v.17'), Synset('give_birth.v.01'), Synset('take.v.35'), Synset('stations.n.01'), Synset('station.n.01'), Synset('place.n.10'), Synset('station.n.03'), Synset('post.n.01'), Synset('station.n.05'), Synset('station.v.01'), Synset('congress.n.01'), Synset('congress.n.02'), Synset('congress.n.03'), Synset('sexual_intercourse.n.01'), Synset('detriment.n.01'), Synset('jot_down.v.01'), Synset('allegation.n.01'), Synset('allegation.n.02'), Synset('mending.n.01'), Synset('repair.n.01'), Synset('repair.v.01'), Synset('mend.v.02'), Synset('city.n.01'), Synset('city.n.02'), Synset('city.n.03'), Synset('glen.n.01'), Synset('inlay.v.01'), Synset('inlaid.s.01'), Synset('hatchet_man.n.02'), Synset('e ...
